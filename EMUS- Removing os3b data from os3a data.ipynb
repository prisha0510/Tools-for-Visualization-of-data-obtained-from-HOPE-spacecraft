# %%
#This notebook was prepared by Prisha Jain

# %%
from astropy.io import fits

# %%
def integrate_brightness(wavelength, radiance, line_range):
# figure out which spectral bins are in the wavelength range
    spectral_pos = np.logical_and(line_range[0] < wavelength, wavelength <line_range[1])
    spectral_pos = np.where(spectral_pos)
# figure our how wide the spectral bins are
    wavelength_diff = np.diff(wavelength)
# figure out the contribution in R from each spectral bin and add it up
    return np.nansum(radiance[spectral_pos]*wavelength_diff[spectral_pos]) # R/nm * nm = R

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#in the first 4 files, we have the os3a data, and in the next 4 files, we have the os3b data

# %%
data1 = fits.open(r"C:\Users\prish\Downloads\emm_emu_l2a_20210625t001445_0071_os3a_sw1of4_f_v01-13.fits.gz")#enter the path of the file you wish to open
test_int1 = data1['CAL'].data['CORRECTED_CNTS'].shape[0]//2
test_observation_image1 = np.zeros(data1['CAL'].data['RADIANCE'].shape[:2])
for i_int in range(data1['CAL'].data['RADIANCE'].shape[0]):
    for i_spa in range(data1['CAL'].data['RADIANCE'].shape[1]):
        test_observation_image1[i_int, i_spa] =integrate_brightness(data1['WAVELENGTH'].data['WAVELENGTH_L2A'][0, i_spa],data1['CAL'].data['RADIANCE'][i_int, i_spa],[121.56-2.0,121.56+2.0])

fig, ax = plt.subplots(1, dpi=100)
img1 = ax.imshow(test_observation_image1)
cbar = plt.colorbar(img1)
cbar.set_label('121.56 nm radiance [R],25 June, 06:01 LST')
test_observation_image1.shape
# Out:
# (285, 64)

# %%
data2 = fits.open(r"C:\Users\prish\Downloads\emm_emu_l2a_20210625t002005_0071_os3a_sw2of4_f_v01-13.fits.gz")
test_int2 = data2['CAL'].data['CORRECTED_CNTS'].shape[0]//2
test_observation_image2 = np.zeros(data2['CAL'].data['RADIANCE'].shape[:2])
for i_int in range(data2['CAL'].data['RADIANCE'].shape[0]):
    for i_spa in range(data2['CAL'].data['RADIANCE'].shape[1]):
        test_observation_image2[i_int, i_spa] =integrate_brightness(data2['WAVELENGTH'].data['WAVELENGTH_L2A'][0, i_spa],data2['CAL'].data['RADIANCE'][i_int, i_spa],[121.56-2.0,121.56+2.0])

fig, ax = plt.subplots(1, dpi=100)
img2 = ax.imshow(test_observation_image2)
cbar = plt.colorbar(img2)
cbar.set_label('121.56 nm radiance [R],25 June, 06:04 LST')
test_observation_image2.shape
# Out:
# (285, 64)

# %%
data3 = fits.open(r"C:\Users\prish\Downloads\emm_emu_l2a_20210625t002525_0071_os3a_sw3of4_f_v01-13.fits.gz")
test_int3 = data3['CAL'].data['CORRECTED_CNTS'].shape[0]//2
test_observation_image3 = np.zeros(data3['CAL'].data['RADIANCE'].shape[:2])
for i_int in range(data3['CAL'].data['RADIANCE'].shape[0]):
    for i_spa in range(data3['CAL'].data['RADIANCE'].shape[1]):
        test_observation_image3[i_int, i_spa] =integrate_brightness(data3['WAVELENGTH'].data['WAVELENGTH_L2A'][0, i_spa],data3['CAL'].data['RADIANCE'][i_int, i_spa],[121.56-2.0,121.56+2.0])

fig, ax = plt.subplots(1, dpi=100)
img3 = ax.imshow(test_observation_image3)
cbar = plt.colorbar(img3)
cbar.set_label('121.56 nm radiance [R],25 June, 06:06 LST')
test_observation_image3.shape
# Out:
# (285, 64)

# %%
data4 = fits.open(r"C:\Users\prish\Downloads\emm_emu_l2a_20210625t003045_0071_os3a_sw4of4_f_v01-13.fits.gz")
test_int4 = data4['CAL'].data['CORRECTED_CNTS'].shape[0]//2
test_observation_image4 = np.zeros(data4['CAL'].data['RADIANCE'].shape[:2])
for i_int in range(data4['CAL'].data['RADIANCE'].shape[0]):
    for i_spa in range(data4['CAL'].data['RADIANCE'].shape[1]):
        test_observation_image4[i_int, i_spa] =integrate_brightness(data4['WAVELENGTH'].data['WAVELENGTH_L2A'][0, i_spa],data4['CAL'].data['RADIANCE'][i_int, i_spa],[121.56-2.0,121.56+2.0])

fig, ax = plt.subplots(1, dpi=100)
img4 = ax.imshow(test_observation_image4)
cbar = plt.colorbar(img4)
cbar.set_label('121.56 nm radiance [R],25 June, 06:09 LST')
test_observation_image4.shape
# Out:
# (285, 64)

# %%
#os3b data below:

# %%
data5 = fits.open(r"C:\Users\prish\Downloads\emm_emu_l2a_20210625t164605_0071_os3b_sw1of4_f_v01-13.fits.gz")
test_int5 = data5['CAL'].data['CORRECTED_CNTS'].shape[0]//2
test_observation_image5 = np.zeros(data5['CAL'].data['RADIANCE'].shape[:2])
for i_int in range(data5['CAL'].data['RADIANCE'].shape[0]):
    for i_spa in range(data5['CAL'].data['RADIANCE'].shape[1]):
        test_observation_image5[i_int, i_spa] =integrate_brightness(data5['WAVELENGTH'].data['WAVELENGTH_L2A'][0, i_spa],data5['CAL'].data['RADIANCE'][i_int, i_spa],[121.56-2.0,121.56+2.0])

fig, ax = plt.subplots(1, dpi=100)
img5 = ax.imshow(test_observation_image5)
cbar = plt.colorbar(img5)
cbar.set_label('121.56 nm radiance [R],25 June, 06:04 LST')
test_observation_image5.shape
# Out:
# (285, 64)

# %%
data6 = fits.open(r"C:\Users\prish\Downloads\emm_emu_l2a_20210625t165125_0071_os3b_sw2of4_f_v01-13.fits.gz")
test_int6 = data6['CAL'].data['CORRECTED_CNTS'].shape[0]//2
test_observation_image6 = np.zeros(data6['CAL'].data['RADIANCE'].shape[:2])
for i_int in range(data6['CAL'].data['RADIANCE'].shape[0]):
    for i_spa in range(data6['CAL'].data['RADIANCE'].shape[1]):
        test_observation_image6[i_int, i_spa] =integrate_brightness(data6['WAVELENGTH'].data['WAVELENGTH_L2A'][0, i_spa],data6['CAL'].data['RADIANCE'][i_int, i_spa],[121.56-2.0,121.56+2.0])

fig, ax = plt.subplots(1, dpi=100)
img6 = ax.imshow(test_observation_image6)
cbar = plt.colorbar(img6)
cbar.set_label('121.56 nm radiance [R],25 June, 06:06 LST')
test_observation_image6.shape
# Out:
# (285, 64)

# %%
data7 = fits.open(r"C:\Users\prish\Downloads\emm_emu_l2a_20210625t165645_0071_os3b_sw3of4_f_v01-13.fits.gz")
test_int7 = data7['CAL'].data['CORRECTED_CNTS'].shape[0]//2
test_observation_image7 = np.zeros(data7['CAL'].data['RADIANCE'].shape[:2])
for i_int in range(data7['CAL'].data['RADIANCE'].shape[0]):
    for i_spa in range(data7['CAL'].data['RADIANCE'].shape[1]):
        test_observation_image7[i_int, i_spa] =integrate_brightness(data7['WAVELENGTH'].data['WAVELENGTH_L2A'][0, i_spa],data7['CAL'].data['RADIANCE'][i_int, i_spa],[121.56-2.0,121.56+2.0])

fig, ax = plt.subplots(1, dpi=100)
img7 = ax.imshow(test_observation_image7)
cbar = plt.colorbar(img7)
cbar.set_label('121.56 nm radiance [R],25 June, 18:12 LST')
test_observation_image7.shape
# Out:
# (285, 64)

# %%
data8 = fits.open(r"C:\Users\prish\Downloads\emm_emu_l2a_20210625t170205_0071_os3b_sw4of4_f_v01-13.fits.gz")
test_int8 = data8['CAL'].data['CORRECTED_CNTS'].shape[0]//2
test_observation_image8 = np.zeros(data8['CAL'].data['RADIANCE'].shape[:2])
for i_int in range(data8['CAL'].data['RADIANCE'].shape[0]):
    for i_spa in range(data8['CAL'].data['RADIANCE'].shape[1]):
        test_observation_image8[i_int, i_spa] =integrate_brightness(data8['WAVELENGTH'].data['WAVELENGTH_L2A'][0, i_spa],data8['CAL'].data['RADIANCE'][i_int, i_spa],[121.56-2.0,121.56+2.0])

fig, ax = plt.subplots(1, dpi=100)
img8 = ax.imshow(test_observation_image8)
cbar = plt.colorbar(img8)
cbar.set_label('121.56 nm radiance [R],25 June, 18:16 LST')
test_observation_image8.shape
# Out:
# (285, 64)

# %%
#removing os3b data from os3a data
ar1=test_observation_image1-test_observation_image5
ar2=test_observation_image2-test_observation_image6
ar3=test_observation_image3-test_observation_image7
ar4=test_observation_image4-test_observation_image8

# %%
plt.imshow(ar1)

# %%
plt.imshow(ar2)

# %%
plt.imshow(ar3)

# %%
plt.imshow(ar4)

# %%
#delete some columns to cut image and resize it, the values here might have to be modified depending upon the file 
ar1 = np.delete(ar1, np.s_[0:7], 1)
ar2 = np.delete(ar2, np.s_[0:7], 1)
ar3 = np.delete(ar3, np.s_[0:7], 1)
ar4 = np.delete(ar4, np.s_[0:7], 1)

# %%
#delete some columns to cut image and resize it, the values here might have to be modified depending upon the file
ar1 = np.delete(ar1, np.s_[35:57], 1)
ar2 = np.delete(ar2, np.s_[35:57], 1)
ar3 = np.delete(ar3, np.s_[35:57], 1)
ar4 = np.delete(ar4, np.s_[35:57], 1)

# %%
#delete some rows to cut image and resize it, the values here might have to be modified depending upon the file
ar1 = np.delete(ar1, np.s_[0:29], 0)
ar3 = np.delete(ar3, np.s_[0:29], 0)

# %%
#delete some rows to cut image and resize it, the values here might have to be modified depending upon the file
ar1 = np.delete(ar1, np.s_[226:256], 0)
ar3 = np.delete(ar3, np.s_[226:256], 0)

# %%
from PIL import Image
import scipy.misc
from scipy import ndimage

# %%
#creating arrays of 0 which will be appended to images to make them of the proper dimensions
a1=np.zeros((226,95))
a2=np.zeros((226,96))
a3=np.zeros((95,226))
a4=np.zeros((96,226))

# %%
#rotating images by 0,45,90 and 135 degrees
im1= ndimage.rotate(ar1,0)
im2= ndimage.rotate(ar2,135)
im3= ndimage.rotate(ar3,90)
im4= ndimage.rotate(ar4,45)

# %%
arr1=np.hstack((a1,im1,a2))
fig1, ax = plt.subplots(1, dpi=100)
img1 = ax.imshow(arr1)
cbar = plt.colorbar(img1)

# %%
arr2=np.vstack((a3,im3,a4))
fig2, ax = plt.subplots(1, dpi=100)
img2 = ax.imshow(arr2)
cbar = plt.colorbar(img2)

# %%
plt.imshow(im4)
plt.colorbar
# Out:
# <function matplotlib.pyplot.colorbar(mappable=None, cax=None, ax=None, **kw)>

# %%
plt.imshow(im2)
plt.colorbar
# Out:
# <function matplotlib.pyplot.colorbar(mappable=None, cax=None, ax=None, **kw)>

# %%
# when producing the image by averaging the pixels method, we only take into consideration those pixels whose value is more than a minimum threshold which we've set to be 100
array_final=np.zeros((im1.shape[0],im1.shape[0]))
for i in range(im1.shape[0]):
    for j in range(im1.shape[0]):
        c=0
        val1=arr2[i][j]
        val2=arr1[i][j]
        val3=im2[i][j]
        val4=im4[i][j]
        if(arr2[i][j]>100):
            c=c+1
        if(arr1[i][j]>100):
            c=c+1
        if(im2[i][j]>100):
            c=c+1
        if(im4[i][j]>100):
            c=c+1
        if(c!=0):
            array_final[i][j]=(val1+val2+val3+val4)/c
        else:
            array_final[i][j]=0
        
plt.imshow(array_final)
plt.colorbar()
plt.clim(0,7000)
