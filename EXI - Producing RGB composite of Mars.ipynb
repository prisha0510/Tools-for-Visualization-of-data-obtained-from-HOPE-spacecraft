# %%
# This notebook was created by Prisha Jain

# %%
# importing all the necessary libraries required
import pylab as py
import matplotlib.pyplot as plt
from astropy.visualization import make_lupton_rgb
from astropy.io import fits
import numpy as np
import cv2
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import glob
from PIL import Image as im
from skimage.transform import resize
from numpy import asarray
from numpy import clip
from PIL import Image

# %%
#producing RGB Composites, of various files and days

# %%
r_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T015148_0099_xos1_f635_r_v04-01.fits.gz")
g_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T015205_0099_xos1_f546_r_v04-01.fits.gz")
b_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T015216_0099_xos1_f437_r_v04-01.fits.gz")
r = r_name[1].data
g = g_name[1].data
b = b_name[1].data
r = resize(r, (g.shape[0], g.shape[1]))
red = r/np.nanmax(r)
green = g/np.nanmax(g)
blue = b/np.nanmax(b)

rgb_default = make_lupton_rgb(red*1,green*0.95,blue*0.8,Q=1,stretch=1)
plt.title("28 Aug, 11:35 LST, XOS1,-0.38")
plt.imshow(rgb_default, origin='lower')

# %%
r_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T020148_0099_xos1_f635_r_v04-01.fits.gz")
g_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T020205_0099_xos1_f546_r_v04-01.fits.gz")
b_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T020216_0099_xos1_f437_r_v04-01.fits.gz")
r = r_name[1].data
g = g_name[1].data
b = b_name[1].data
r = resize(r, (g.shape[0], g.shape[1]))
red = r/np.nanmax(r)
green = g/np.nanmax(g)
blue = b/np.nanmax(b)

rgb_default = make_lupton_rgb(red*1,green*0.95,blue*0.8,Q=1,stretch=1)

plt.title("28 Aug, 11:42 LST, XOS1,-1.31")
plt.imshow(rgb_default, origin='lower')

# %%
r_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T021148_0099_xos1_f635_r_v04-01.fits.gz")
g_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T021205_0099_xos1_f546_r_v04-01.fits.gz")
b_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T021216_0099_xos1_f437_r_v04-01.fits.gz")
r = r_name[1].data
g = g_name[1].data
b = b_name[1].data
r = resize(r, (g.shape[0], g.shape[1]))
red = r/np.nanmax(r)
green = g/np.nanmax(g)
blue = b/np.nanmax(b)
rgb_default = make_lupton_rgb(red*0.95,green*0.95,blue*0.8,Q=1,stretch=1)
plt.title("28 Aug, 11:51 LST, XOS1,-2.28")
plt.imshow(rgb_default, origin='lower')

# %%
r_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T022148_0099_xos1_f635_r_v04-01.fits.gz")
g_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T022205_0099_xos1_f546_r_v04-01.fits.gz")
b_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T022216_0099_xos1_f437_r_v04-01.fits.gz")
r = r_name[1].data
g = g_name[1].data
b = b_name[1].data
r = resize(r, (g.shape[0], g.shape[1]))
red = r/np.nanmax(r)
green = g/np.nanmax(g)
blue = b/np.nanmax(b)

rgb_default = make_lupton_rgb(red*0.97,green*0.95,blue*0.8,Q=1,stretch=1)
plt.title("28 Aug, 11:59 LST, XOS1,-3.26")
plt.imshow(rgb_default, origin='lower')

# %%
r_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T023148_0099_xos1_f635_r_v04-01.fits.gz")
g_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T023205_0099_xos1_f546_r_v04-01.fits.gz")
b_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T023216_0099_xos1_f437_r_v04-01.fits.gz")
r = r_name[1].data
g = g_name[1].data
b = b_name[1].data
r = resize(r, (g.shape[0], g.shape[1]))
red = r/np.nanmax(r)
green = g/np.nanmax(g)
blue = b/np.nanmax(b)

rgb_default = make_lupton_rgb(red*0.97,green*0.95,blue*0.8,Q=1,stretch=1)
plt.title("28 Aug, 12:08 LST, XOS1,-4.24")
plt.imshow(rgb_default, origin='upper')

# %%
r_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T024148_0099_xos1_f635_r_v04-01.fits.gz")
g_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T024205_0099_xos1_f546_r_v04-01.fits.gz")
b_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T024216_0099_xos1_f437_r_v04-01.fits.gz")
r = r_name[1].data
g = g_name[1].data
b = b_name[1].data
r = resize(r, (g.shape[0], g.shape[1]))
red = r/np.nanmax(r)
green = g/np.nanmax(g)
blue = b/np.nanmax(b)

rgb_default = make_lupton_rgb(red*0.97,green*0.95,blue*0.8,Q=1,stretch=1)
plt.title("28 Aug, 12:16 LST, XOS1,-5.15")
plt.imshow(rgb_default, origin='lower')

# %%
r_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T025148_0099_xos1_f635_r_v04-01.fits.gz")
g_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T025205_0099_xos1_f546_r_v04-01.fits.gz")
b_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T025216_0099_xos1_f437_r_v04-01.fits.gz")
r = r_name[1].data
g = g_name[1].data
b = b_name[1].data
r = resize(r, (g.shape[0], g.shape[1]))
red = r/np.nanmax(r)
green = g/np.nanmax(g)
blue = b/np.nanmax(b)

rgb_default = make_lupton_rgb(red*0.97,green*0.95,blue*0.8,Q=1,stretch=1)
plt.title("28 Aug, 12:24 LST, XOS1,-6.07")
plt.imshow(rgb_default, origin='lower')

# %%
r_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T033951_0099_xos2_f635_r_v04-01.fits.gz")
g_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T034008_0099_xos2_f546_r_v04-01.fits.gz")
b_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T034019_0099_xos2_f437_r_v04-01.fits.gz")
r = r_name[1].data
g = g_name[1].data
b = b_name[1].data

red = r/np.nanmax(r)
green = g/np.nanmax(g)
blue = b/np.nanmax(b)

rgb_default = make_lupton_rgb(red*0.97,green*0.95,blue*0.8,Q=1,stretch=1)
plt.title("28 Aug, 13:03 LST, XOS2")
plt.imshow(rgb_default, origin='lower')

# %%
r_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T054406_0099_xos1_f635_r_v04-01.fits.gz")
g_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T054423_0099_xos1_f546_r_v04-01.fits.gz")
b_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T054434_0099_xos1_f437_r_v04-01.fits.gz")
r = r_name[1].data
g = g_name[1].data
b = b_name[1].data
r = resize(r, (g.shape[0], g.shape[1]))
red = r/np.nanmax(r)
green = g/np.nanmax(g)
blue = b/np.nanmax(b)

rgb_default = make_lupton_rgb(red*0.97,green*0.95,blue*0.8,Q=1,stretch=1)
plt.title("28 Aug, 14:39 LST, XOS1,-18.91")
plt.imshow(rgb_default, origin='lower')

# %%
r_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T061936_0099_xos2_f635_r_v04-01.fits.gz")
g_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T061953_0099_xos2_f546_r_v04-01.fits.gz")
b_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T062004_0099_xos2_f437_r_v04-01.fits.gz")
r = r_name[1].data
g = g_name[1].data
b = b_name[1].data

red = r/np.nanmax(r)
green = g/np.nanmax(g)
blue = b/np.nanmax(b)

rgb_default = make_lupton_rgb(red*0.97,green*0.95,blue*0.8,Q=1,stretch=1)
plt.title("28 Aug, 15:05 LST, XOS2,-20.63")
plt.imshow(rgb_default, origin='lower')

# %%
r_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T010012_0099_xos2_f635_r_v04-01.fits.gz")
g_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T010029_0099_xos2_f546_r_v04-01.fits.gz")
b_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T010040_0099_xos2_f437_r_v04-01.fits.gz")
r = r_name[1].data
g = g_name[1].data
b = b_name[1].data

red = r/np.nanmax(r)
green = g/np.nanmax(g)
blue = b/np.nanmax(b)

rgb_default = make_lupton_rgb(red*0.97,green*0.95,blue*0.8,Q=1,stretch=1)
plt.title("28 Aug, 10:51 LST, XOS2,4.65")
plt.imshow(rgb_default, origin='upper')

# %%
r_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T010012_0099_xos2_f635_r_v04-01.fits.gz")
g_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T010029_0099_xos2_f546_r_v04-01.fits.gz")
b_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T010040_0099_xos2_f437_r_v04-01.fits.gz")
r = r_name[1].data
g = g_name[1].data
b = b_name[1].data

red = r/np.nanmax(r)
green = g/np.nanmax(g)
blue = b/np.nanmax(b)

rgb_default = make_lupton_rgb(red*0.97,green*0.95,blue*0.8,Q=1,stretch=1)
plt.title("28 Aug, 10:51 LST, XOS2,4.65")
plt.imshow(rgb_default, origin='lower')

# %%
r_name = fits.open(r"C:\Users\prish\Downloads\emm_exi_l2a_20210613T212811_0066_xos2_f635_r_v04-01.fits.gz")
g_name = fits.open(r"C:\Users\prish\Downloads\emm_exi_l2a_20210613T212828_0066_xos2_f546_r_v04-01.fits.gz")
b_name = fits.open(r"C:\Users\prish\Downloads\emm_exi_l2a_20210613T212839_0066_xos2_f437_r_v04-01.fits.gz")
r = r_name[1].data
g = g_name[1].data
b = b_name[1].data

red = r/np.nanmax(r)
green = g/np.nanmax(g)
blue = b/np.nanmax(b)

rgb_default = make_lupton_rgb(red*0.97,green*0.95,blue*0.8,Q=1,stretch=1)
plt.title("13 June, 10:05 LST, XOS2,21.64")

plt.imshow(rgb_default)

# %%
r_name = fits.open(r"C:\Users\prish\Downloads\emm_exi_l2a_20210627T140506_0072_xos2_f635_r_v04-01.fits.gz")
g_name = fits.open(r"C:\Users\prish\Downloads\emm_exi_l2a_20210627T140523_0072_xos2_f546_r_v04-01.fits.gz")
b_name = fits.open(r"C:\Users\prish\Downloads\emm_exi_l2a_20210627T140534_0072_xos2_f437_r_v04-01.fits.gz")
r = r_name[1].data
g = g_name[1].data
b = b_name[1].data

red = r/np.nanmax(r)
green = g/np.nanmax(g)
blue = b/np.nanmax(b)

rgb_default = make_lupton_rgb(red*0.97,green*0.95,blue*0.8,Q=1,stretch=1)
plt.title("27 June, 10:47 LST, XOS2,17.02")

plt.imshow(rgb_default)

# %%
r_name = fits.open(r"C:\Users\prish\Downloads\emm_exi_l2a_20210627T184832_0072_xos1_f635_r_v04-01.fits.gz")
g_name = fits.open(r"C:\Users\prish\Downloads\emm_exi_l2a_20210627T184849_0072_xos1_f546_r_v04-01.fits.gz")
b_name = fits.open(r"C:\Users\prish\Downloads\emm_exi_l2a_20210627T184900_0072_xos1_f437_r_v04-01.fits.gz")
r = r_name[1].data
g = g_name[1].data
b = b_name[1].data
r = resize(r, (g.shape[0], g.shape[1]))
red = r/np.nanmax(r)
green = g/np.nanmax(g)
blue = b/np.nanmax(b)

rgb_default = make_lupton_rgb(red*0.97,green*0.95,blue*0.8,Q=1,stretch=1)
plt.title("27 June, 14:43 LST, XOS1,-8.40")

plt.imshow(rgb_default,origin='lower')

# %%
r_name = fits.open(r"C:\Users\prish\Downloads\emm_exi_l2a_20210823T082852_0097_xos1_f635_r_v04-01.fits.gz")
g_name = fits.open(r"C:\Users\prish\Downloads\emm_exi_l2a_20210823T082909_0097_xos1_f546_r_v04-01.fits.gz")
b_name = fits.open(r"C:\Users\prish\Downloads\emm_exi_l2a_20210823T082920_0097_xos1_f437_r_v04-01.fits.gz")
r = r_name[1].data
g = g_name[1].data
b = b_name[1].data
r = resize(r, (g.shape[0], g.shape[1]))
red = r/np.nanmax(r)
green = g/np.nanmax(g)
blue = b/np.nanmax(b)

rgb_default = make_lupton_rgb(red*0.97,green*0.95,blue*0.8,Q=1,stretch=1)
plt.title("23 Aug, 08:09 LST, XOS1,20.51")

plt.imshow(rgb_default, origin='upper')

# %%
r_name = fits.open(r"C:\Users\prish\Downloads\emm_exi_l2a_20210719T205840_0082_xos2_f635_r_v04-01.fits.gz")
g_name = fits.open(r"C:\Users\prish\Downloads\emm_exi_l2a_20210719T205857_0082_xos2_f546_r_v04-01.fits.gz")
b_name = fits.open(r"C:\Users\prish\Downloads\emm_exi_l2a_20210719T205908_0082_xos2_f437_r_v04-01.fits.gz")
r = r_name[1].data
g = g_name[1].data
b = b_name[1].data

red = r/np.nanmax(r)
green = g/np.nanmax(g)
blue = b/np.nanmax(b)

rgb_default = make_lupton_rgb(red*0.97,green*0.95,blue*0.9,Q=0.01,stretch=0.9)
plt.title("19 July, 03:57 LST, XOS2,19.05")

plt.imshow(rgb_default,origin='lower')

# %%
r_name = fits.open(r"C:\Users\prish\Downloads\emm_exi_l2a_20210620T143111_0069_xos1_f635_r_v04-01.fits.gz")
g_name = fits.open(r"C:\Users\prish\Downloads\emm_exi_l2a_20210620T143128_0069_xos1_f546_r_v04-01.fits.gz")
b_name = fits.open(r"C:\Users\prish\Downloads\emm_exi_l2a_20210620T143139_0069_xos1_f437_r_v04-01.fits.gz")
r = r_name[1].data
g = g_name[1].data
b = b_name[1].data
r = resize(r, (g.shape[0], g.shape[1]))
red = r/np.nanmax(r)
green = g/np.nanmax(g)
blue = b/np.nanmax(b)

rgb_default = make_lupton_rgb(red*0.9,green*0.95,blue*0.8,Q=1,stretch=1)
plt.title("20 June, 08:02 LST, XOS1,25.10")

plt.imshow(rgb_default, origin='lower')

# %%
r_name = fits.open(r"C:\Users\prish\Downloads\emm_exi_l2a_20210830T083249_0100_xos1_f635_r_v04-01.fits.gz")
g_name = fits.open(r"C:\Users\prish\Downloads\emm_exi_l2a_20210830T083306_0100_xos1_f546_r_v04-01.fits.gz")
b_name = fits.open(r"C:\Users\prish\Downloads\emm_exi_l2a_20210830T083317_0100_xos1_f437_r_v04-01.fits.gz")
r = r_name[1].data
g = g_name[1].data
b = b_name[1].data
r = resize(r, (g.shape[0], g.shape[1]))
red = r/np.nanmax(r)
green = g/np.nanmax(g)
blue = b/np.nanmax(b)

rgb_default = make_lupton_rgb(red*0.9,green*0.95,blue*0.8,Q=1,stretch=1)
plt.title("30 Aug, 11:37 LST, XOS1,-1.25")

plt.imshow(rgb_default, origin='lower')
