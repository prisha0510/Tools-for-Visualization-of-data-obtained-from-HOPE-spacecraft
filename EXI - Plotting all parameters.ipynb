# %%
#This notebook was created by Prisha Jain

# %%
#importing the relevant libraries 
import pylab as py
import matplotlib.pyplot as plt
from astropy.visualization import make_lupton_rgb
from astropy.io import fits
import numpy as np
import cv2
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import glob
from PIL import Image as im
from skimage.transform import resize

# %%
#opening .fits file
r_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T010012_0099_xos2_f635_r_v04-01.fits.gz")
g_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T010029_0099_xos2_f546_r_v04-01.fits.gz")
b_name = fits.open(r"C:\Users\prish\Desktop\28 Aug\data\emm_exi_l2a_20210828T010040_0099_xos2_f437_r_v04-01.fits.gz")

# %%
#loading all the different parameters for data collected through red filter
sci_r = r_name[1].data
dqf_r = r_name[2].data
pha_r = r_name[5].data
look_r = r_name[6].data
lat_r = r_name[7].data
long_r = r_name[8].data
height_r = r_name[9].data
rng_r = r_name[10].data
ina_r = r_name[11].data
ema_r = r_name[12].data

# %%
#loading all the different parameters for data collected through blue filter
sci_b = b_name[1].data
dqf_b = b_name[2].data
pha_b = b_name[5].data
look_b = b_name[6].data
lat_b = b_name[7].data
long_b = b_name[8].data
height_b = b_name[9].data
rng_b = b_name[10].data
ina_b = b_name[11].data
ema_b = b_name[12].data

# %%
#loading all the different parameters for data collected through green filter
sci_g = g_name[1].data
dqf_g = g_name[2].data
pha_g = g_name[5].data
look_g = g_name[6].data
lat_g = g_name[7].data
long_g = g_name[8].data
height_g = g_name[9].data
rng_g = g_name[10].data
ina_g = g_name[11].data
ema_g = g_name[12].data

# %%
plt.imshow(sci_r)
plt.colorbar()

# %%
plt.imshow(sci_g)
plt.colorbar()

# %%
plt.imshow(sci_b)
plt.colorbar()

# %%
plt.imshow(dqf_r)
plt.colorbar()

# %%
plt.imshow(dqf_g)
plt.colorbar()

# %%
plt.imshow(dqf_b)
plt.colorbar()

# %%
plt.imshow(pha_r)
plt.colorbar()

# %%
plt.imshow(pha_g)
plt.colorbar()

# %%
plt.imshow(pha_b)
plt.colorbar()

# %%
plt.imshow(look_r)
plt.colorbar()

# %%
plt.imshow(look_b)
plt.colorbar()

# %%
plt.imshow(look_g)
plt.colorbar()

# %%
plt.imshow(lat_r)
plt.colorbar()

# %%
plt.imshow(long_r)
plt.colorbar()

# %%
plt.imshow(long_g)
plt.colorbar()

# %%
plt.imshow(height_r)
plt.colorbar()

# %%
plt.imshow(height_g)
plt.colorbar()

# %%
plt.imshow(rng_g)
plt.colorbar()

# %%
plt.imshow(rng_r)
plt.colorbar()

# %%
plt.imshow(ina_r)
plt.colorbar()

# %%
plt.imshow(ina_r)
plt.colorbar()

# %%
plt.imshow(ema_r)
plt.colorbar()
