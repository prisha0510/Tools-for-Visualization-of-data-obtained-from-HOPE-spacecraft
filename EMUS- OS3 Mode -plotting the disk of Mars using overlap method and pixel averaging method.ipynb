# %%
#This notebook was created by Prisha Jain

# %%
from astropy.io import fits

# %%
#function to integrate brightness
def integrate_brightness(wavelength, radiance, line_range):
# figure out which spectral bins are in the wavelength range
    spectral_pos = np.logical_and(line_range[0] < wavelength, wavelength <line_range[1])
    spectral_pos = np.where(spectral_pos)
# figure our how wide the spectral bins are
    wavelength_diff = np.diff(wavelength)
# figure out the contribution in R from each spectral bin and add it up
    return np.nansum(radiance[spectral_pos]*wavelength_diff[spectral_pos]) # R/nm * nm = R

# %%
import numpy as np
import matplotlib.pyplot as plt
test_spa = 45

# %%
data7 = fits.open(r"C:\Users\prish\Downloads\emm_emu_l2a_20211129t020340_0140_os3a_sw1of4_f_v01-08.fits.gz")# copy paste the path of the file you wish to open
test_int7 = data7['CAL'].data['CORRECTED_CNTS'].shape[0]//2
test_observation_image7 = np.zeros(data7['CAL'].data['RADIANCE'].shape[:2])
for i_int in range(data7['CAL'].data['RADIANCE'].shape[0]):
    for i_spa in range(data7['CAL'].data['RADIANCE'].shape[1]):
        test_observation_image7[i_int, i_spa] =integrate_brightness(data7['WAVELENGTH'].data['WAVELENGTH_L2A'][0, i_spa],data7['CAL'].data['RADIANCE'][i_int, i_spa],[121.56-2.0,121.56+2.0])

fig, ax = plt.subplots(1, dpi=100)
img7 = ax.imshow(test_observation_image7)
cbar = plt.colorbar(img7)
cbar.set_label('121.56 nm radiance [R],9 May, 17:19 LST')
test_observation_image7.shape
# Out:
# (285, 48)

# %%
test_observation_image7 = np.delete(test_observation_image7, np.s_[0:7], 1) #cutting the data so as to remove the NaN entries and non zero entries from the side

# %%
test_observation_image7 = np.delete(test_observation_image7, np.s_[35:57], 1)

# %%
plt.imshow(test_observation_image7)
test_observation_image7.shape
# Out:
# (285, 35)

# %%
data8 = fits.open(r"C:\Users\prish\Downloads\emm_emu_l2a_20211129t020900_0140_os3a_sw2of4_f_v01-08.fits.gz")
test_int8 = data8['CAL'].data['CORRECTED_CNTS'].shape[0]//2
test_observation_image8 = np.zeros(data8['CAL'].data['RADIANCE'].shape[:2])
for i_int in range(data8['CAL'].data['RADIANCE'].shape[0]):
    for i_spa in range(data8['CAL'].data['RADIANCE'].shape[1]):
        test_observation_image8[i_int, i_spa] =integrate_brightness(data8['WAVELENGTH'].data['WAVELENGTH_L2A'][0, i_spa],data8['CAL'].data['RADIANCE'][i_int, i_spa],[121.56-2.0,121.56+2.0])
fig, ax = plt.subplots(1, dpi=100)
img8 = ax.imshow(test_observation_image8)
cbar = plt.colorbar(img8)
cbar.set_label('121.56 nm radiance [R],9 May, 17:25 LST')

# %%
test_observation_image8 = np.delete(test_observation_image8, np.s_[0:7], 1)

# %%
test_observation_image8 = np.delete(test_observation_image8, np.s_[35:57], 1)

# %%
plt.imshow(test_observation_image8)
test_observation_image8.shape
# Out:
# (285, 35)

# %%
data9 = fits.open(r"C:\Users\prish\Downloads\emm_emu_l2a_20211129t021420_0140_os3a_sw3of4_f_v01-08.fits.gz")
test_int9 = data9['CAL'].data['CORRECTED_CNTS'].shape[0]//2
test_observation_image9 = np.zeros(data9['CAL'].data['RADIANCE'].shape[:2])
for i_int in range(data9['CAL'].data['RADIANCE'].shape[0]):
    for i_spa in range(data9['CAL'].data['RADIANCE'].shape[1]):
        test_observation_image9[i_int, i_spa] =integrate_brightness(data9['WAVELENGTH'].data['WAVELENGTH_L2A'][0, i_spa],data9['CAL'].data['RADIANCE'][i_int, i_spa],[121.56-2.0,121.56+2.0])
fig, ax = plt.subplots(1, dpi=100)
img9 = ax.imshow(test_observation_image9)
cbar = plt.colorbar(img9)
cbar.set_label('121.56 nm radiance [R],9 May, 17:30 LST')

# %%
test_observation_image9 = np.delete(test_observation_image9, np.s_[0:7], 1)

# %%
test_observation_image9 = np.delete(test_observation_image9, np.s_[35:57], 1)

# %%
plt.imshow(test_observation_image9)
test_observation_image9.shape
# Out:
# (285, 35)

# %%
data10 = fits.open(r"C:\Users\prish\Downloads\emm_emu_l2a_20211129t021940_0140_os3a_sw4of4_f_v01-08.fits.gz")
test_int10 = data10['CAL'].data['CORRECTED_CNTS'].shape[0]//2
test_observation_image10 = np.zeros(data10['CAL'].data['RADIANCE'].shape[:2])
for i_int in range(data10['CAL'].data['RADIANCE'].shape[0]):
    for i_spa in range(data10['CAL'].data['RADIANCE'].shape[1]):
        test_observation_image10[i_int, i_spa] =integrate_brightness(data10['WAVELENGTH'].data['WAVELENGTH_L2A'][0, i_spa],data10['CAL'].data['RADIANCE'][i_int, i_spa],[121.56-2.0,121.56+2.0])
fig, ax = plt.subplots(1, dpi=100)
img10 = ax.imshow(test_observation_image10)
cbar = plt.colorbar(img10)
cbar.set_label('121.56 nm radiance [R],9 May, 17:35 LST')

# %%
test_observation_image10 = np.delete(test_observation_image10, np.s_[0:7], 1)

# %%
test_observation_image10 = np.delete(test_observation_image10, np.s_[35:57], 1)

# %%
plt.imshow(test_observation_image10)
test_observation_image10.shape
# Out:
# (285, 35)

# %%
test_observation_image7 = np.delete(test_observation_image7, np.s_[0:29], 0)

# %%
test_observation_image7 = np.delete(test_observation_image7, np.s_[226:256], 0)

# %%
test_observation_image9 = np.delete(test_observation_image9, np.s_[0:29], 0)

# %%
test_observation_image9 = np.delete(test_observation_image9, np.s_[226:256], 0)

# %%
#importing necessary libraries
from PIL import Image
import scipy.misc
from scipy import ndimage

# %%
import sys
import numpy
numpy.set_printoptions(threshold=sys.maxsize)
im7= ndimage.rotate(test_observation_image7,0)
plt.imshow(im7)
im7.shape
# Out:
# (226, 35)

# %%
#rotating the image by 135 degrees
im8= ndimage.rotate(test_observation_image8,135)
plt.imshow(im8)
im8.shape
# Out:
# (226, 226)

# %%
#rotating the image by 90 degrees
im9= ndimage.rotate(test_observation_image9,90)
plt.imshow(im9)
im9.shape
# Out:
# (35, 226)

# %%
#rotating the image by 45 degrees
im10= ndimage.rotate(test_observation_image10,45)
plt.imshow(im10)
im10.shape
# Out:
# (226, 226)

# %%
#creating an array of zeros , which we will append to our images later so as to make 4 images of same dimensions so that we can overlay them one on top of the other
ar1=np.zeros((226,95))
plt.imshow(ar1)

# %%
ar2=np.zeros((226,96))
plt.imshow(ar2)

# %%
#creating an image with the main disk at the centre, with dimensions such that we can overlap the 4 images produced by rotating the images by 0, 45, 90 and 135 degrees respectively.
arr1=np.hstack((ar1,im7,ar2))
fig1, ax = plt.subplots(1, dpi=100)
img1 = ax.imshow(arr1)
cbar = plt.colorbar(img1)

# %%
ar3=np.zeros((95,226))
plt.imshow(ar3)

# %%
ar4=np.zeros((96,226))
plt.imshow(ar4)

# %%
arr2=np.vstack((ar3,im9,ar4))
fig2, ax = plt.subplots(1, dpi=100)
img2 = ax.imshow(arr2)
cbar = plt.colorbar(img2)

# %%
#producing the image of the disk by overlaying images
fig1 = plt.figure(frameon=False)
i9=plt.imshow(arr2,alpha=1)
i7=plt.imshow(arr1,alpha=0.4)
i10=plt.imshow(im10,alpha=0.4)
i8=plt.imshow(im8,alpha=0.3)
plt.show(fig1)

# %%
# when producing the image by averaging the pixels method, we only take into consideration those pixels whose value is more than a minimum threshold which we've set to be 100
array_final=np.zeros((im10.shape[0],im10.shape[0]))
for i in range(im10.shape[0]):
    for j in range(im10.shape[0]):
        c=0
        val1=arr2[i][j]
        val2=arr1[i][j]
        val3=im10[i][j]
        val4=im8[i][j]
        if(arr2[i][j]>100):
            c=c+1
       
        if(arr1[i][j]>100):
            c=c+1

        if(im8[i][j]>100):
            c=c+1
       
        if(im10[i][j]>100):
            c=c+1
        
        if(c!=0):
            array_final[i][j]=(val1+val2+val3+val4)/c
        else:
            array_final[i][j]=0
        
plt.imshow(array_final)
plt.colorbar()
plt.clim(0,7000)
